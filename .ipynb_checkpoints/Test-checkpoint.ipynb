# %%
from auto_eda import *

# %%
diabetes = pd.read_csv('diabetes.csv')
diabetes['Outcome'] = np.where(diabetes['Outcome'] == 1, 'Heart Disease', 'No Heart Disease')

# %%
report = auto_eda(diabetes, target_variable = 'Outcome')

# %%
report.get_samples()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 668            6       98             58             33      190  34.0
# 324            2      112             75             32        0  35.7
# 624            2      108             64              0        0  30.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age           Outcome
# 0                       0.627   50     Heart Disease
# 1                       0.351   31  No Heart Disease
# 2                       0.672   32     Heart Disease
# 668                     0.430   43  No Heart Disease
# 324                     0.148   21  No Heart Disease
# 624                     0.158   21  No Heart Disease
# 765                     0.245   30  No Heart Disease
# 766                     0.349   47     Heart Disease
# 767                     0.315   23  No Heart Disease

# %%
report.get_missings()
# Out:
# There is no missing value, please check if the missings have been encoded with non-NAN value.
# Use argument missing_tag for encoded missing values

# %%
report.histogram()

# %%
report.correlation()
# Out:
# <style  type="text/css" >
#     #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow0_col0 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow0_col1 {
#             background-color:  #e58195;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow0_col2 {
#             background-color:  #e68699;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow0_col3 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow0_col4 {
#             background-color:  #d73d5c;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow0_col5 {
#             background-color:  #de5c76;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow0_col6 {
#             background-color:  #da4b68;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow0_col7 {
#             background-color:  #d8e3f1;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow1_col0 {
#             background-color:  #dd5671;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow1_col1 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow1_col2 {
#             background-color:  #de5f79;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow1_col3 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow1_col4 {
#             background-color:  #eda6b4;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow1_col5 {
#             background-color:  #e47a90;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow1_col6 {
#             background-color:  #dd5a74;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow1_col7 {
#             background-color:  #e78a9d;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow2_col0 {
#             background-color:  #df617a;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow2_col1 {
#             background-color:  #e0657d;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow2_col2 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow2_col3 {
#             background-color:  #e47a90;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow2_col4 {
#             background-color:  #db4d69;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow2_col5 {
#             background-color:  #ea97a8;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow2_col6 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow2_col7 {
#             background-color:  #e68699;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow3_col0 {
#             background-color:  #d94563;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow3_col1 {
#             background-color:  #e27389;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow3_col2 {
#             background-color:  #eca4b3;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow3_col3 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow3_col4 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow3_col5 {
#             background-color:  #f9e2e6;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow3_col6 {
#             background-color:  #eb9dac;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow3_col7 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow4_col0 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow4_col1 {
#             background-color:  #f3c5ce;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow4_col2 {
#             background-color:  #e27288;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow4_col3 {
#             background-color:  #fae8ec;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow4_col4 {
#             background-color:  #4479bb;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow4_col5 {
#             background-color:  #ea97a8;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow4_col6 {
#             background-color:  #e993a4;
#             color:  #000000;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow4_col7 {
#             background-color:  #d94563;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow5_col0 {
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#             max-width:  60px;
#             font-size:  10pt;
#         }    #T_6beace68_c7a6_11ea_b7cb_8cc84b05a5earow5_col1 {
